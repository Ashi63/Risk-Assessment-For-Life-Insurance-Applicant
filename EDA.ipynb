# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import os
from pathlib import Path

# %%
working_dir = str(Path('/content/drive/MyDrive/'))
raw_data_dir = str(Path(os.path.join(working_dir,'Raw_Data')))
raw_data = os.path.join(raw_data_dir,'DATA.csv')
training_data_dir = str(Path(os.path.join(working_dir,'Data_For_Training')))

# %%
print(working_dir)
print(raw_data_dir)
print(raw_data)
print(training_data_dir)
# Out:
# /content/drive/MyDrive/Capstone Project Great Learning
# /content/drive/MyDrive/Capstone Project Great Learning/Raw_Data
# /content/drive/MyDrive/Capstone Project Great Learning/Raw_Data/DATA.csv
# /content/drive/MyDrive/Capstone Project Great Learning/Data_For_Training

# %%
# loading the data
data = pd.read_csv(raw_data)

# %%
# peek at your data
data.head()
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
# 3   7               1             D4              10        0.487179
# 4   8               1             D2              26        0.230769
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  ...  \
# 0               2               1               1  0.641791  0.581818  ...
# 1               2               3               1  0.059701  0.600000  ...
# 2               2               3               1  0.029851  0.745455  ...
# 3               2               3               1  0.164179  0.672727  ...
# 4               2               3               1  0.417910  0.654545  ...
#
#    Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# ...

# %%
# understanding the volume of the data
data.shape
# Out:
# (59381, 128)

# %%
# understanding the numerical summary
data.describe()
# Out:
#                  Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# count  59381.000000    59381.000000    59381.000000    59381.000000
# mean   39507.211515        1.026355       24.415655        0.328952
# std    22815.883089        0.160191        5.072885        0.282562
# min        2.000000        1.000000        1.000000        0.000000
# 25%    19780.000000        1.000000       26.000000        0.076923
# 50%    39487.000000        1.000000       26.000000        0.230769
# 75%    59211.000000        1.000000       26.000000        0.487179
# max    79146.000000        2.000000       38.000000        1.000000
#
#        Product_Info_5  Product_Info_6  Product_Info_7       Ins_Age  \
# count    59381.000000    59381.000000    59381.000000  59381.000000
# mean         2.006955        2.673599        1.043583      0.405567
# std          0.083107        0.739103        0.291949      0.197190
# min          2.000000        1.000000        1.000000      0.000000
# ...

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Data columns (total 128 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    Id                   int64
#  1    Product_Info_1       int64
#  2    Product_Info_2       object
#  3    Product_Info_3       int64
#  4    Product_Info_4       float64
#  5    Product_Info_5       int64
#  6    Product_Info_6       int64
#  7    Product_Info_7       int64
#  8    Ins_Age              float64
#  9    Ht                   float64
#  10   Wt                   float64
#  11   BMI                  float64
#  12   Employment_Info_1    float64
#  13   Employment_Info_2    int64
#  14   Employment_Info_3    int64
#  15   Employment_Info_4    float64
#  16   Employment_Info_5    int64
#  17   Employment_Info_6    float64
#  18   InsuredInfo_1        int64
#  19   InsuredInfo_2        int64
#  20   InsuredInfo_3        int64
#  21   InsuredInfo_4        int64
# ...

# %%
numerical_columns = data.select_dtypes(include=['int64','float64']).columns.values.tolist()
numerical_columns
# Out:
# ['Id',
#  'Product_Info_1',
#  'Product_Info_3',
#  'Product_Info_4',
#  'Product_Info_5',
#  'Product_Info_6',
#  'Product_Info_7',
#  'Ins_Age',
#  'Ht',
#  'Wt',
#  'BMI',
#  'Employment_Info_1',
#  'Employment_Info_2',
#  'Employment_Info_3',
#  'Employment_Info_4',
#  'Employment_Info_5',
#  'Employment_Info_6',
#  'InsuredInfo_1',
#  'InsuredInfo_2',
#  'InsuredInfo_3',
#  'InsuredInfo_4',
#  'InsuredInfo_5',
#  'InsuredInfo_6',
#  'InsuredInfo_7',
#  'Insurance_History_1',
#  'Insurance_History_2',
#  'Insurance_History_3',
#  'Insurance_History_4',
#  'Insurance_History_5',
#  'Insurance_History_7',
#  'Insurance_History_8',
#  'Insurance_History_9',
#  'Family_Hist_1',
#  'Family_Hist_2',
#  'Family_Hist_3',
#  'Family_Hist_4',
#  'Family_Hist_5',
#  'Medical_History_1',
#  'Medical_History_2',
#  'Medical_History_3',
#  'Medical_History_4',
#  'Medical_History_5',
#  'Medical_History_6',
#  'Medical_History_7',
#  'Medical_History_8',
#  'Medical_History_9',
# ...

# %%
categorical_column = data.select_dtypes(include=['object']).columns.values.tolist()
categorical_column
# Out:
# ['Product_Info_2']

# %%
# checking for the duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
missing_value_df = pd.DataFrame(data.isnull().sum(),columns=['Missing_Values'])
missing_value_df['Percentage_of_Missing_Values']=missing_value_df/len(data)*100
missing_value_df = missing_value_df.sort_values(by='Missing_Values',ascending=False)
missing_value_df = missing_value_df[missing_value_df['Missing_Values']!=0]
print(missing_value_df)
print("\n")
print("Number of Missing Values Columns: ",len(missing_value_df))
# Out:
#                      Missing_Values  Percentage_of_Missing_Values
# Medical_History_10            58824                     99.061990
# Medical_History_32            58274                     98.135767
# Medical_History_24            55580                     93.598963
# Medical_History_15            44596                     75.101463
# Family_Hist_5                 41811                     70.411411
# Family_Hist_3                 34241                     57.663226
# Family_Hist_2                 28656                     48.257860
# Insurance_History_5           25396                     42.767889
# Family_Hist_4                 19184                     32.306630
# Employment_Info_6             10854                     18.278574
# Medical_History_1              8889                     14.969435
# Employment_Info_4              6779                     11.416110
# Employment_Info_1                19                      0.031997
#
#
# Number of Missing Values Columns:  13

# %% [markdown]
# Observation:-
# - we can observer that number of missing value columns in the data set are 13.
# - we will have to deal with the missing values later with differnt strategies as missing values numbers are varying.

# %%
# checking the correlation of the columns with our target variable i.e "Response"

# %%
data.corr()['Response']
# Out:
# Id                    0.000462
# Product_Info_1        0.014692
# Product_Info_3       -0.067432
# Product_Info_4        0.202434
# Product_Info_5       -0.001486
#                         ...
# Medical_Keyword_45    0.004852
# Medical_Keyword_46   -0.054693
# Medical_Keyword_47   -0.060104
# Medical_Keyword_48   -0.159557
# Response              1.000000
# Name: Response, Length: 127, dtype: float64

# %%
correlation_with_Response = pd.DataFrame(data.corr()['Response'])
correlation_with_Response = correlation_with_Response.sort_values(ascending=False,by='Response')
print("Top 10 Features with strong positive correlation: \n",correlation_with_Response.head(10))
print("\n")
print("Top 10 Features with strong negative correlation: \n",correlation_with_Response.tail(10))
print("\n")
# Out:
# Top 10 Features with strong positive correlation:
#                      Response
# Response            1.000000
# Medical_History_23  0.286584
# Medical_History_15  0.277311
# Medical_History_4   0.239896
# Medical_History_39  0.220176
# Product_Info_4      0.202434
# Medical_History_6   0.159230
# Medical_History_32  0.144536
# Medical_History_13  0.134863
# Medical_History_40  0.131519
#
#
# Top 10 Features with strong negative correlation:
#                       Response
# Medical_History_30  -0.114870
# Employment_Info_3   -0.116408
# Insurance_History_2 -0.122196
# Medical_History_16  -0.137542
# Medical_Keyword_48  -0.159557
# Ins_Age             -0.209610
# Medical_Keyword_3   -0.257706
# Medical_Keyword_15  -0.259169
# Wt                  -0.351395
# BMI                 -0.381601

# %% [markdown]
# Observation:-
#
# Corelation values is between -1 and 1
# - -1 means strong nagative corelation.
# -  0 means no corelation.
# -  1 means strong poitive corealtion.
#
# In this data correlation values are not strong.
#
# - A correlation coefficient of zero indicates that no linear relationship exists between two continuous variables, and a correlation coefficient of −1 or +1 indicates a perfect linear relationship.
#
# - The strength of relationship can be anywhere between −1 and +1. The stronger the correlation, the closer the correlation coefficient comes to ±1.
#
# - If the coefficient is a positive number, the variables are directly related (i.e., as the value of one variable goes up, the value of the other also tends to do so).
#
# - If, on the other hand, the coefficient is a negative number, the variables are inversely related (i.e., as the value of one variable goes up, the value of the other tends to go down).

# %%
data.cov()
# Out:
#                               Id  Product_Info_1  Product_Info_3  \
# Id                  5.205645e+08      -10.487825     -216.353109
# Product_Info_1     -1.048782e+01        0.025661        0.022407
# Product_Info_3     -2.163531e+02        0.022407       25.734167
# Product_Info_4     -1.878864e+01        0.002708        0.069914
# Product_Info_5     -7.954738e+00        0.000928        0.010716
# ...                          ...             ...             ...
# Medical_Keyword_45 -7.589754e-01       -0.000125       -0.031423
# Medical_Keyword_46  5.618077e+00       -0.000156       -0.000716
# Medical_Keyword_47  3.820596e+00        0.000098       -0.012046
# Medical_Keyword_48 -5.808917e+00       -0.000308        0.052811
# Response            2.588616e+01        0.005782       -0.840424
#
#                     Product_Info_4  Product_Info_5  Product_Info_6  \
# Id                      -18.788643       -7.954738       84.951121
# ...

# %% [markdown]
# - Covariance can be positive, negative, or zero.
# - A positive covariance means that the two variables tend to increase or decrease together.
# - A negative covariance means that the two variables tend to move in opposite directions.
#
# - A zero covariance means that the two variables are not related.

# %% [markdown]
# Let's Do Univariate Analysis

# %%
figure,axes = plt.subplots(nrows=2,ncols=3,figsize=(15,8))
sns.distplot(data['Product_Info_1'],ax = axes[0,0])
sns.distplot(data['Product_Info_3'],ax = axes[0,1])
sns.distplot(data['Product_Info_4'],ax = axes[0,2])
sns.distplot(data['Product_Info_5'],ax = axes[1,0])
sns.distplot(data['Product_Info_6'],ax = axes[1,1])
sns.distplot(data['Product_Info_7'],ax = axes[1,2])
# Out:
# <AxesSubplot:xlabel='Product_Info_7', ylabel='Density'>

# %% [markdown]
# Observation:-
# - most of the product columns are multimodal.
# - perhaps signifies that these columns may be of differnt catogories of products.

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(15,8))
sns.distplot(data['Ins_Age'],ax = axes[0,0])
sns.distplot(data['Ht'],ax = axes[0,1])
sns.distplot(data['Wt'],ax = axes[1,0])
sns.distplot(data['BMI'],ax = axes[1,1])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %%
print("Min Value of Age: ",data['Ins_Age'].max())
print("Max Value of Age: ",data['Ins_Age'].min())
print("Min Value of Height: ",data['Ht'].max())
print("Max Value of Height: ",data['Ht'].min())
print("Min Value of Wt: ",data['Wt'].max())
print("Max Value of Wt: ",data['Wt'].min())
print("Min Value of BMI: ",data['BMI'].max())
print("Max Value of BMI: ",data['BMI'].min())
# Out:
# Min Value of Age:  1.0
# Max Value of Age:  0.0
# Min Value of Height:  1.0
# Max Value of Height:  0.0
# Min Value of Wt:  1.0
# Max Value of Wt:  0.0
# Min Value of BMI:  1.0
# Max Value of BMI:  0.0

# %% [markdown]
# Observations:-
# - all four column seems to be in range of 0 and 1.
# - signifies that these columns are normalizes using min max scaling.
# - as calculating the minimum and maximum values also proves.

# %%
figure,axes = plt.subplots(nrows=2,ncols=3,figsize=(15,8))
sns.distplot(data['Employment_Info_1'],ax = axes[0,0])
sns.distplot(data['Employment_Info_2'],ax = axes[0,1])
sns.distplot(data['Employment_Info_3'],ax = axes[0,2])
sns.distplot(data['Employment_Info_4'],ax = axes[1,0])
sns.distplot(data['Employment_Info_5'],ax = axes[1,1])
sns.distplot(data['Employment_Info_6'],ax = axes[1,2])
# Out:
# <AxesSubplot:xlabel='Employment_Info_6', ylabel='Density'>

# %% [markdown]
# Observations:-
# - Employment info columns mix of both categorical colums and numerical columns.

# %%
figure,axes = plt.subplots(nrows=3,ncols=3,figsize=(15,10))
sns.distplot(data['InsuredInfo_1'],ax = axes[0,0])
sns.distplot(data['InsuredInfo_2'],ax = axes[0,1])
sns.distplot(data['InsuredInfo_3'],ax = axes[0,2])
sns.distplot(data['InsuredInfo_4'],ax = axes[1,0])
sns.distplot(data['InsuredInfo_5'],ax = axes[1,1])
sns.distplot(data['InsuredInfo_6'],ax = axes[1,2])
sns.distplot(data['InsuredInfo_7'],ax = axes[2,0])
# Out:
# <AxesSubplot:xlabel='InsuredInfo_7', ylabel='Density'>

# %%
figure,axes = plt.subplots(nrows=2,ncols=4,figsize=(15,8))
sns.distplot(data['Insurance_History_1'],ax = axes[0,0])
sns.distplot(data['Insurance_History_2'],ax = axes[0,1])
sns.distplot(data['Insurance_History_3'],ax = axes[0,2])
sns.distplot(data['Insurance_History_4'],ax = axes[0,3])
sns.distplot(data['Insurance_History_5'],ax = axes[1,0])
sns.distplot(data['Insurance_History_7'],ax = axes[1,1])
sns.distplot(data['Insurance_History_8'],ax = axes[1,2])
sns.distplot(data['Insurance_History_9'],ax = axes[1,3])
# Out:
# <AxesSubplot:xlabel='Insurance_History_9', ylabel='Density'>

# %% [markdown]
# Observations:-
# - most of the insured history columns are multimodal and within range betweeen 1 and 3.

# %%
figure,axes = plt.subplots(nrows=2,ncols=3,figsize=(15,12))
sns.distplot(data['Family_Hist_1'],ax = axes[0,0])
sns.distplot(data['Family_Hist_2'],ax = axes[0,1])
sns.distplot(data['Family_Hist_3'],ax = axes[0,2])
sns.distplot(data['Family_Hist_4'],ax = axes[1,0])
sns.distplot(data['Family_Hist_5'],ax = axes[1,1])
# Out:
# <AxesSubplot:xlabel='Family_Hist_5', ylabel='Density'>

# %% [markdown]
# Observations:-
# - Family history columns are mostly apprx. normally distributed except Family_Hist_1 (which means having 3 categories 1,2,3) and Family_History_3 (which is slightly left skewed)

# %%
figure,axes = plt.subplots(nrows=11,ncols=4,figsize=(20,20))
sns.distplot(data['Medical_History_1'],ax = axes[0,0])
sns.distplot(data['Medical_History_2'],ax = axes[0,1])
sns.distplot(data['Medical_History_3'],ax = axes[0,2])
sns.distplot(data['Medical_History_4'],ax = axes[0,3])
sns.distplot(data['Medical_History_5'],ax = axes[1,0])
sns.distplot(data['Medical_History_6'],ax = axes[1,1])
sns.distplot(data['Medical_History_7'],ax = axes[1,2])
sns.distplot(data['Medical_History_8'],ax = axes[1,3])
sns.distplot(data['Medical_History_9'],ax = axes[2,0])
sns.distplot(data['Medical_History_10'],ax = axes[2,1])
sns.distplot(data['Medical_History_11'],ax = axes[2,2])
sns.distplot(data['Medical_History_12'],ax = axes[2,3])
sns.distplot(data['Medical_History_13'],ax = axes[3,0])
sns.distplot(data['Medical_History_14'],ax = axes[3,1])
sns.distplot(data['Medical_History_15'],ax = axes[3,2])
sns.distplot(data['Medical_History_16'],ax = axes[3,3])
sns.distplot(data['Medical_History_17'],ax = axes[4,0])
sns.distplot(data['Medical_History_18'],ax = axes[4,1])
sns.distplot(data['Medical_History_19'],ax = axes[4,2])
sns.distplot(data['Medical_History_20'],ax = axes[4,3])
sns.distplot(data['Medical_History_21'],ax = axes[5,0])
sns.distplot(data['Medical_History_22'],ax = axes[5,1])
sns.distplot(data['Medical_History_23'],ax = axes[5,2])
sns.distplot(data['Medical_History_24'],ax = axes[5,3])
sns.distplot(data['Medical_History_25'],ax = axes[6,0])
sns.distplot(data['Medical_History_26'],ax = axes[6,1])
sns.distplot(data['Medical_History_27'],ax = axes[6,2])
sns.distplot(data['Medical_History_28'],ax = axes[6,3])
sns.distplot(data['Medical_History_29'],ax = axes[7,0])
sns.distplot(data['Medical_History_30'],ax = axes[7,1])
sns.distplot(data['Medical_History_31'],ax = axes[7,2])
sns.distplot(data['Medical_History_32'],ax = axes[7,3])
sns.distplot(data['Medical_History_33'],ax = axes[8,0])
sns.distplot(data['Medical_History_34'],ax = axes[8,1])
sns.distplot(data['Medical_History_35'],ax = axes[8,2])
sns.distplot(data['Medical_History_36'],ax = axes[8,3])
sns.distplot(data['Medical_History_37'],ax = axes[9,0])
sns.distplot(data['Medical_History_38'],ax = axes[9,1])
sns.distplot(data['Medical_History_39'],ax = axes[9,2])
sns.distplot(data['Medical_History_40'],ax = axes[9,3])
sns.distplot(data['Medical_History_41'],ax = axes[10,0])
# Out:
# <AxesSubplot:xlabel='Medical_History_41', ylabel='Density'>

# %% [markdown]
# Observation :-
# - Most of the columns are multimodal signifing the categories.

# %%
figure,axes = plt.subplots(nrows=12,ncols=4,figsize=(20,20))
sns.distplot(data['Medical_Keyword_1'],ax = axes[0,0])
sns.distplot(data['Medical_Keyword_2'],ax = axes[0,1])
sns.distplot(data['Medical_Keyword_3'],ax = axes[0,2])
sns.distplot(data['Medical_Keyword_4'],ax = axes[0,3])
sns.distplot(data['Medical_Keyword_5'],ax = axes[1,0])
sns.distplot(data['Medical_Keyword_6'],ax = axes[1,1])
sns.distplot(data['Medical_Keyword_7'],ax = axes[1,2])
sns.distplot(data['Medical_Keyword_8'],ax = axes[1,3])
sns.distplot(data['Medical_Keyword_9'],ax = axes[2,0])
sns.distplot(data['Medical_Keyword_10'],ax = axes[2,1])
sns.distplot(data['Medical_Keyword_11'],ax = axes[2,2])
sns.distplot(data['Medical_Keyword_12'],ax = axes[2,3])
sns.distplot(data['Medical_Keyword_13'],ax = axes[3,0])
sns.distplot(data['Medical_Keyword_14'],ax = axes[3,1])
sns.distplot(data['Medical_Keyword_15'],ax = axes[3,2])
sns.distplot(data['Medical_Keyword_16'],ax = axes[3,3])
sns.distplot(data['Medical_Keyword_17'],ax = axes[4,0])
sns.distplot(data['Medical_Keyword_18'],ax = axes[4,1])
sns.distplot(data['Medical_Keyword_19'],ax = axes[4,2])
sns.distplot(data['Medical_Keyword_20'],ax = axes[4,3])
sns.distplot(data['Medical_Keyword_21'],ax = axes[5,0])
sns.distplot(data['Medical_Keyword_22'],ax = axes[5,1])
sns.distplot(data['Medical_Keyword_23'],ax = axes[5,2])
sns.distplot(data['Medical_Keyword_24'],ax = axes[5,3])
sns.distplot(data['Medical_Keyword_25'],ax = axes[6,0])
sns.distplot(data['Medical_Keyword_26'],ax = axes[6,1])
sns.distplot(data['Medical_Keyword_27'],ax = axes[6,2])
sns.distplot(data['Medical_Keyword_28'],ax = axes[6,3])
sns.distplot(data['Medical_Keyword_29'],ax = axes[7,0])
sns.distplot(data['Medical_Keyword_30'],ax = axes[7,1])
sns.distplot(data['Medical_Keyword_31'],ax = axes[7,2])
sns.distplot(data['Medical_Keyword_32'],ax = axes[7,3])
sns.distplot(data['Medical_Keyword_33'],ax = axes[8,0])
sns.distplot(data['Medical_Keyword_34'],ax = axes[8,1])
sns.distplot(data['Medical_Keyword_35'],ax = axes[8,2])
sns.distplot(data['Medical_Keyword_36'],ax = axes[8,3])
sns.distplot(data['Medical_Keyword_37'],ax = axes[9,0])
sns.distplot(data['Medical_Keyword_38'],ax = axes[9,1])
sns.distplot(data['Medical_Keyword_39'],ax = axes[9,2])
sns.distplot(data['Medical_Keyword_40'],ax = axes[9,3])
sns.distplot(data['Medical_Keyword_41'],ax = axes[10,0])
sns.distplot(data['Medical_Keyword_42'],ax = axes[10,1])
sns.distplot(data['Medical_Keyword_43'],ax = axes[10,2])
sns.distplot(data['Medical_Keyword_44'],ax = axes[10,3])
sns.distplot(data['Medical_Keyword_45'],ax = axes[11,0])
sns.distplot(data['Medical_Keyword_46'],ax = axes[11,1])
sns.distplot(data['Medical_Keyword_47'],ax = axes[11,2])
sns.distplot(data['Medical_Keyword_48'],ax = axes[11,3])
# Out:
# <AxesSubplot:xlabel='Medical_Keyword_48', ylabel='Density'>

# %%
print("Min Value of Age: ",data['Medical_Keyword_1'].max())
print("Max Value of Age: ",data['Medical_Keyword_1'].min())
print(data['Medical_Keyword_1'].value_counts())
# Out:
# Min Value of Age:  1
# Max Value of Age:  0
# 0    56887
# 1     2494
# Name: Medical_Keyword_1, dtype: int64

# %% [markdown]
# Observation:-
# - all most all the column values have either 0 or 1.
# - signifies might be of 0 and 1 categories.
# - or may be yes no king of questions answered.

# %%
sns.countplot(data['Response'])
# Out:
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %% [markdown]
# Observation:-
# - we can clearly see that the Response variable is imbalanced.
# - we have to deal with the imbalance of data set later.
# - The difficulty in separating the small class from the prevalent class is the key issue of the small class problem

# %% [markdown]
# Observation:-
# - Note Product_Info_2 is not be dealt with as it is alpha numerica column.

# %%
fig,axes = plt.subplots(nrows=2 ,ncols=2,figsize=(12,10))
sns.scatterplot(x=data["Response"],y=data['Ins_Age'],ax = axes[0,0])
sns.scatterplot(x=data["Response"],y=data['Ht'],ax = axes[0,1])
sns.scatterplot(x=data["Response"],y=data['Wt'],ax=axes[1,0])
sns.scatterplot(x=data["Response"],y=data['BMI'],ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='Response', ylabel='BMI'>

# %%
# checking for missing values in all the data columns
def checking_missing_values(data):
  """This function gives details of missing values and return a dataframe
     with two columns, missing values count and the percentage of missing values.
     -> Takes original dataframe as parameter
     <- Returns dataframe with details of missing values
  """
  missing_values_details = pd.DataFrame(data.isnull().sum(),columns=['missing_values']) 
  missing_values_details['missing_values_%']=data.isnull().sum()/len(data)*100
  return missing_values_details.sort_values(ascending=False,by='missing_values_%')



# removing columns with more than 50% missing values in all the data columns
def remove_missing_value_columns(data,per_missing_value):
  """This method removes column with more than 40 % missing values.
     <- Return data frame with colums removed with more than 40% percent missing values
  """
  missing_values_col_list = missing_values_details[missing_values_details['missing_values_%']>per_missing_value].index.values.tolist()
  total_missing_values = missing_values_details[missing_values_details['missing_values_%']!=0].index.values.tolist()
  print("Total Missing Values Columns List : ",total_missing_values)
  print("Total Number of columns with missing values: ",len(total_missing_values))
  print("Number Columns with missing values more than 40%: ",len(missing_values_col_list))
  print("Shape of Data Before droping column: ",data.shape)
  data1 = data.drop(columns=missing_values_col_list,axis=1)
  print("Shape of Data After droping column: ",data1.shape)
  print("No. of columns droped: ",data.shape[1]-data1.shape[1])
  return data1

missing_values_details = checking_missing_values(data)
print("Missing Value details: \n",missing_values_details.head(15))

data = remove_missing_value_columns(data,40)
data


# checking missing values in data columns which are left after
# removing the columns with more than 50% missing values
data2 = checking_missing_values(data)

# getting list of columns with missing values
remaining_colums_with_missing_values = data2[data2['missing_values']!=0].index.values.tolist()
print("\n")
print("List of columns with missing values less than 50% : ",remaining_colums_with_missing_values)
print("Total Number of Columns with missing value less than 50% :",len(remaining_colums_with_missing_values))
print('\n')

# creating a dataframe with missing value columns for analysis.
data_x= data[remaining_colums_with_missing_values]

# checking the details of missing values present
print("Details of missing values:\n",checking_missing_values(data_x))
print('\n')

# calculating mean,median for all our columns with missing values 
mean_Family_Hist_4 = data_x['Family_Hist_4'].mean()
median_Family_Hist_4 = data_x['Family_Hist_4'].median()

mean_Employment_Info_6 = data_x['Employment_Info_6'].mean()
median_Employment_Info_6 = data_x['Employment_Info_6'].median()

mean_Medical_History_1 = data_x['Medical_History_1'].mean()
median_Medical_History_1 = data_x['Medical_History_1'].median()

mean_Employment_Info_4 = data_x['Employment_Info_4'].mean()
median_Employment_Info_4 = data_x['Employment_Info_4'].median()

mean_Employment_Info_1 = data_x['Employment_Info_1'].mean()
median_Employment_Info_1 = data_x['Employment_Info_1'].median()

# filling missing values with mean, and median
data_x['mean_Family_Hist_4']=data_x['Family_Hist_4'].fillna(mean_Family_Hist_4)
data_x['median_Family_Hist_4']=data_x['Family_Hist_4'].fillna(median_Family_Hist_4)

data_x['mean_Employment_Info_6']=data_x['Employment_Info_6'].fillna(mean_Employment_Info_6)
data_x['median_Employment_Info_6']=data_x['Employment_Info_6'].fillna(median_Employment_Info_6)

data_x['mean_Medical_History_1']=data_x['Medical_History_1'].fillna(mean_Medical_History_1)
data_x['median_Medical_History_1']=data_x['Medical_History_1'].fillna(median_Medical_History_1)

data_x['mean_Employment_Info_4']=data_x['Employment_Info_4'].fillna(mean_Employment_Info_4)
data_x['median_Employment_Info_4']=data_x['Employment_Info_4'].fillna(median_Employment_Info_4)


data_x['mean_Employment_Info_1']=data_x['Employment_Info_1'].fillna(mean_Employment_Info_1)
data_x['median_Employment_Info_1']=data_x['Employment_Info_1'].fillna(median_Employment_Info_1)


# plotting and checking the distributions of columns when normal, when filled with mean, when filled with median
fig,axes = plt.subplots(nrows=5,ncols=3,figsize=(12,18))

sns.distplot(data_x['Family_Hist_4'],ax=axes[0,0],label='Normal',color='Red')
sns.distplot(data_x['mean_Family_Hist_4'],ax=axes[0,1],label='Mean',color='Blue')
sns.distplot(data_x['median_Family_Hist_4'],ax=axes[0,2],label='Median',color='Green')


sns.distplot(data_x['Employment_Info_6'],ax=axes[1,0],color='Red')
sns.distplot(data_x['mean_Employment_Info_6'],ax=axes[1,1],color='Blue')
sns.distplot(data_x['median_Employment_Info_6'],ax=axes[1,2],color='Green')

sns.distplot(data_x['Medical_History_1'],ax=axes[2,0],color='Red')
sns.distplot(data_x['mean_Medical_History_1'],ax=axes[2,1],color='Blue')
sns.distplot(data_x['median_Medical_History_1'],ax=axes[2,2],color='Green')

sns.distplot(data_x['Employment_Info_4'],ax=axes[3,0],color='Red')
sns.distplot(data_x['mean_Employment_Info_4'],ax=axes[3,1],color='Blue')
sns.distplot(data_x['median_Employment_Info_4'],ax=axes[3,2],color='Green')


sns.distplot(data_x['Employment_Info_1'],ax=axes[4,0],color='Red')
sns.distplot(data_x['mean_Employment_Info_1'],ax=axes[4,1],color='Blue')
sns.distplot(data_x['median_Employment_Info_1'],ax=axes[4,2],color='Green')
# Out:
# Missing Value details:
#                       missing_values  missing_values_%
# Medical_History_10            58824         99.061990
# Medical_History_32            58274         98.135767
# Medical_History_24            55580         93.598963
# Medical_History_15            44596         75.101463
# Family_Hist_5                 41811         70.411411
# Family_Hist_3                 34241         57.663226
# Family_Hist_2                 28656         48.257860
# Insurance_History_5           25396         42.767889
# Family_Hist_4                 19184         32.306630
# Employment_Info_6             10854         18.278574
# Medical_History_1              8889         14.969435
# Employment_Info_4              6779         11.416110
# Employment_Info_1                19          0.031997
# Medical_Keyword_13                0          0.000000
# Medical_Keyword_14                0          0.000000
# ...

# %% [markdown]
# Observation:-
# - Clearly we can see that for Family_Hist_4, Employment_Info_6 there is change in distributions when fillinf missing values with mean and median, which is not good.
#
# - For other we can go ahead with median, as  distributions there has no change in the distribution.
#
# - We will impute the values in our preprocessing module.

# %% [markdown]
# ## Overall Observation:-
# - As various observations are drawn from our EDA, in our preprocessing module we will do following preprocessing to get our data ready for training.
#   1. There are missing values in our data set we have to draw strategies to impute them as so that distribution will not change.
#   2. Also apart from the some normalized data columns we have to scale the other columns which are not in same scale.
#   3. Splitting our data for training and testing.
#   4. Save train and testing data from model training.
